# %% [markdown]
# # Stars Wars Survey

# %% [markdown]
# While waiting for Star Wars: The Force Awakens to come out, the team at FiveThirtyEight became interested in answering some questions about Star Wars fans. In particular, they wondered: does the rest of America realize that “The Empire Strikes Back” is clearly the best of the bunch?
#
# The team needed to collect data addressing this question. To do this, they surveyed Star Wars fans using the online tool SurveyMonkey. They received 835 total responses, which you can download from their GitHub repository.
#
# For this project, we'll clean and explore the dataset in Jupyter notebook. To see a sample notebook containing all of the answers, visit the project's GitHub repository.

# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.set_option('display.max_columns', 500)

# %%
star_wars = pd.read_csv("star_wars.csv", encoding="ISO-8859-1")
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                                Yes
# 1    3292879538                                                 No
# 2    3292765271                                                Yes
# 3    3292763116                                                Yes
# 4    3292731220                                                Yes
# 5    3292719380                                                Yes
# 6    3292684787                                                Yes
# 7    3292663732                                                Yes
# 8    3292654043                                                Yes
# 9    3292640424                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                                Yes
# 1                                                NaN
# ...

# %%
star_wars.shape
# Out:
# (1186, 38)

# %%
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %% [markdown]
# ## Cleaning and Mapping Yes/No Columns

# %%
cols_to_convert = [
    "Have you seen any of the 6 films in the Star Wars franchise?",
    "Do you consider yourself to be a fan of the Star Wars film franchise?"
]

# %%
star_wars.loc[:, cols_to_convert]
# Out:
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                                   Yes
# 1                                                    No
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 1181                                                Yes
# 1182                                                Yes
# 1183                                                 No
# 1184                                                Yes
# 1185                                                Yes
#
#      Do you consider yourself to be a fan of the Star Wars film franchise?
# 0                                                   Yes
# 1                                                   NaN
# 2                                                    No
# ...

# %%
star_wars.loc[:, cols_to_convert] = star_wars.loc[:, cols_to_convert] \
                             .applymap(lambda x: True if x == "Yes" else (False if x == "No" else np.NaN))

# %%
star_wars.loc[:, cols_to_convert].head()
# Out:
#    Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                               True
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True

# %% [markdown]
# ## Cleaning and Mapping Checkbox Columns

# %%
movie_mapping = {
    "Star Wars: Episode I  The Phantom Menace": True,
    np.nan: False,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True
}

# %%
for col in star_wars.columns[3:9]:
    star_wars[col] = star_wars[col].map(movie_mapping)

# %%
star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0                                               True
# 1                                              False
# ...

# %%
star_wars = star_wars.rename(
    columns={
        "Which of the following Star Wars films have you seen? Please select all that apply.": "seen_1",
        "Unnamed: 4": "seen_2",
        "Unnamed: 5": "seen_3",
        "Unnamed: 6": "seen_4",
        "Unnamed: 7": "seen_5",
        "Unnamed: 8": "seen_6"
    }
)

star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 0    True    True    True    True    True    True
# 1   False   False   False   False   False   False
# 2    True    True    True   False   False   False
# ...

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# %%
star_wars = star_wars.rename(columns={
        "Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.": "ranking_1",
        "Unnamed: 10": "ranking_2",
        "Unnamed: 11": "ranking_3",
        "Unnamed: 12": "ranking_4",
        "Unnamed: 13": "ranking_5",
        "Unnamed: 14": "ranking_6"
        })

star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  ranking_1  ranking_2  \
# 0    True    True    True    True    True    True        3.0        2.0
# ...

# %%
mean_movie_rankings = star_wars.iloc[:, 9:15].mean()

# %%
mean_movie_rankings
# Out:
# ranking_1    3.732934
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    3.047847
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
mean_movie_rankings.plot.bar()

# %% [markdown]
# ## Finding the Most Viewed Movie

# %%
seen_cols = ["seen_{}".format(i) for i in range(1, 7)]

# %%
no_of_seens = star_wars.loc[:, seen_cols].sum()
no_of_seens
# Out:
# seen_1    673
# seen_2    571
# seen_3    550
# seen_4    607
# seen_5    758
# seen_6    738
# dtype: int64

# %%
no_of_seens.plot.bar()

# %% [markdown]
# ## Exploring the Data by Binary Segments

# %%
males = star_wars[star_wars["Gender"] == "Male"]
females = star_wars[star_wars["Gender"] == "Female"]

# %%
males.iloc[:, 9:15].mean().plot.bar()

# %%
females.iloc[:, 9:15].mean().plot.bar()

# %%
males.iloc[:, 3:9].sum().plot.bar()
plt.show()

females.iloc[:, 3:9].sum().plot.bar()
plt.show()
